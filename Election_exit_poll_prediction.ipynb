# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_ED = pd.read_excel("Election_Data.xlsx",sheet_name="Election_Dataset_Two Classes")

# %%
df_ED = df_ED.drop('Unnamed: 0',axis=1)

# %%
df_ED.head()
# Out:
#      vote  age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0  Labour   43                       3                        3      4      1
# 1  Labour   36                       4                        4      4      4
# 2  Labour   35                       4                        4      5      2
# 3  Labour   24                       4                        2      2      1
# 4  Labour   41                       2                        2      1      1
#
#    Europe  political.knowledge  gender
# 0       2                    2  female
# 1       5                    2    male
# 2       3                    2    male
# 3       4                    0  female
# 4       6                    2    male

# %%
df_ED.tail()
# Out:
#               vote  age  economic.cond.national  economic.cond.household  \
# 1520  Conservative   67                       5                        3
# 1521  Conservative   73                       2                        2
# 1522        Labour   37                       3                        3
# 1523  Conservative   61                       3                        3
# 1524  Conservative   74                       2                        3
#
#       Blair  Hague  Europe  political.knowledge  gender
# 1520      2      4      11                    3    male
# 1521      4      4       8                    2    male
# 1522      5      4       2                    2    male
# 1523      1      4      11                    2    male
# 1524      2      4      11                    0  female

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
# vote                       1525 non-null object
# age                        1525 non-null int64
# economic.cond.national     1525 non-null int64
# economic.cond.household    1525 non-null int64
# Blair                      1525 non-null int64
# Hague                      1525 non-null int64
# Europe                     1525 non-null int64
# political.knowledge        1525 non-null int64
# gender                     1525 non-null object
# dtypes: int64(7), object(2)
# memory usage: 107.4+ KB

# %%
df_ED.describe().T
# Out:
#                           count       mean        std   min   25%   50%   75%  \
# age                      1525.0  54.182295  15.711209  24.0  41.0  53.0  67.0
# economic.cond.national   1525.0   3.245902   0.880969   1.0   3.0   3.0   4.0
# economic.cond.household  1525.0   3.140328   0.929951   1.0   3.0   3.0   4.0
# Blair                    1525.0   3.334426   1.174824   1.0   2.0   4.0   4.0
# Hague                    1525.0   2.746885   1.230703   1.0   2.0   2.0   4.0
# Europe                   1525.0   6.728525   3.297538   1.0   4.0   6.0  10.0
# political.knowledge      1525.0   1.542295   1.083315   0.0   0.0   2.0   2.0
#
#                           max
# age                      93.0
# economic.cond.national    5.0
# economic.cond.household   5.0
# Blair                     5.0
# Hague                     5.0
# Europe                   11.0
# political.knowledge       3.0

# %% [markdown]
# # Null value condition treatment

# %%
df_ED.isnull().sum() #finding null values
# Out:
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
# vote                       1525 non-null object
# age                        1525 non-null int64
# economic.cond.national     1525 non-null int64
# economic.cond.household    1525 non-null int64
# Blair                      1525 non-null int64
# Hague                      1525 non-null int64
# Europe                     1525 non-null int64
# political.knowledge        1525 non-null int64
# gender                     1525 non-null object
# dtypes: int64(7), object(2)
# memory usage: 107.4+ KB

# %%
dupl=df_ED.duplicated() #calculating duplicate values

# %%
print("Total no of duplicate values = %d" % (dupl.sum()))
df_ED[dupl]
# Out:
# Total no of duplicate values = 8
#               vote  age  economic.cond.national  economic.cond.household  \
# 67          Labour   35                       4                        4
# 626         Labour   39                       3                        4
# 870         Labour   38                       2                        4
# 983   Conservative   74                       4                        3
# 1154  Conservative   53                       3                        4
# 1236        Labour   36                       3                        3
# 1244        Labour   29                       4                        4
# 1438        Labour   40                       4                        3
#
#       Blair  Hague  Europe  political.knowledge  gender
# 67        5      2       3                    2    male
# 626       4      2       5                    2    male
# 870       2      2       4                    3    male
# ...

# %%
df_ED.shape #1525 rows & 9 columns
# Out:
# (1525, 9)

# %% [markdown]
# # Descriptive analysis

# %%
df_ED.vote.value_counts()
# Out:
# Labour          1063
# Conservative     462
# Name: vote, dtype: int64

# %%
df_ED.gender.value_counts()
# Out:
# female    812
# male      713
# Name: gender, dtype: int64

# %%
df_ED.dtypes
# Out:
# vote                       object
# age                         int64
# economic.cond.national      int64
# economic.cond.household     int64
# Blair                       int64
# Hague                       int64
# Europe                      int64
# political.knowledge         int64
# gender                     object
# dtype: object

# %% [markdown]
# # Univariate analysis

# %%
fig, axes = plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(9,9)

a = sns.distplot(df_ED['age'] , ax=axes[0][0])
a.set_title('age Distribution',fontsize=10)

a = sns.boxplot(df_ED['age'] , orient = 'v' , ax=axes[0][1])
a.set_title('age Boxplot',fontsize=10)

a=sns.distplot(df_ED['economic.cond.national'], ax=axes[1][0])
a.set_title('economic Distribution',fontsize=10)

a=sns.boxplot(df_ED['economic.cond.national'],orient='v', ax=axes[1][1])
a.set_title('economic boxplot', fontsize=10)

a=sns.distplot(df_ED['economic.cond.household'], ax=axes[2][0])
a.set_title('economic household Distribution',fontsize=10)

a=sns.boxplot(df_ED['economic.cond.household'],orient='v', ax=axes[2][1])
a.set_title('economic household boxplot', fontsize=10)

a=sns.distplot(df_ED['Blair'], ax=axes[3][0])
a.set_title('Blair Distribution',fontsize=10)

a=sns.boxplot(df_ED['Blair'],orient='v', ax=axes[3][1])
a.set_title('Blair boxplot', fontsize=10)
# Out:
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %%
fig, axes = plt.subplots(nrows=3,ncols=2)
fig.set_size_inches(9,9)

a = sns.distplot(df_ED['Hague'] , ax=axes[0][0])
a.set_title('Hague distribution',fontsize=10)

a = sns.boxplot(df_ED['Hague'] , orient = 'v' , ax=axes[0][1])
a.set_title('Hague Boxplot',fontsize=10)

a = sns.distplot(df_ED['Europe'], ax=axes[1][0])
a.set_title('Europe distribution',fontsize=10)

a = sns.boxplot(df_ED['Europe'],orient='v', ax=axes[1][1])
a.set_title('Europe boxplot', fontsize=10)

a = sns.distplot(df_ED['political.knowledge'], ax=axes[2][0])
a.set_title('political.knowledge Distribution',fontsize=10)

a = sns.boxplot(df_ED['political.knowledge'],orient='v', ax=axes[2][1])
a.set_title('political.knowledge boxplot', fontsize=10)
# Out:
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(x='vote',data=df_ED) #countplot to know no. of vote in both categories

# %%
sns.boxplot(x='vote',y='economic.cond.national',data=df_ED) #pls select between violin & boxplot

# %%
sns.violinplot(x='vote',y='economic.cond.national',data=df_ED,size=8)

# %%
sns.violinplot(x='vote',y='economic.cond.household',data=df_ED,size=8)

# %%
sns.violinplot(x='vote',y='Blair',data=df_ED,size=8)

# %%
sns.violinplot(x='vote',y='Hague',data=df_ED,size=8)

# %%
sns.violinplot(x='vote',y='Europe',data=df_ED,size=8)

# %%
sns.violinplot(x='vote',y='political.knowledge',data=df_ED,size=8)

# %%
sns.pairplot(df_ED)

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df_ED.corr(),annot=True)

# %%
plt.figure(figsize=(15,10))
df_ED.boxplot()
plt.show()

# %%
df1 = df_ED

# %% [markdown]
# # Encoding the data

# %%
df1.select_dtypes(include='object').columns
# Out:
# Index(['vote', 'gender'], dtype='object')

# %%
df1["vote"].unique()
# Out:
# array(['Labour', 'Conservative'], dtype=object)

# %%
df1["gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#one-hot encoding

# %%
df = pd.get_dummies(data= df1, drop_first= True)

# %%
df.head()
# Out:
#    age  economic.cond.national  economic.cond.household  Blair  Hague  Europe  \
# 0   43                       3                        3      4      1       2
# 1   36                       4                        4      4      4       5
# 2   35                       4                        4      5      2       3
# 3   24                       4                        2      2      1       4
# 4   41                       2                        2      1      1       6
#
#    political.knowledge  vote_Labour  gender_male
# 0                    2            1            0
# 1                    2            1            1
# 2                    2            1            1
# 3                    0            1            0
# 4                    2            1            1

# %% [markdown]
# # Splitting the data - 70 train, 30 test

# %%
from sklearn.model_selection import train_test_split
x = df.drop('vote_Labour',axis=1)
y = df['vote_Labour']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
x_train.head()
# Out:
#       age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 1453   62                       3                        3      2      2
# 275    49                       3                        3      2      2
# 1130   74                       4                        4      4      4
# 1153   57                       2                        3      4      2
# 1172   24                       4                        5      4      4
#
#       Europe  political.knowledge  gender_male
# 1453      11                    2            0
# 275        8                    0            0
# 1130       7                    0            1
# 1153       6                    2            0
# 1172       6                    0            1

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.47087709, -0.29551048, -0.15691394, ...,  1.30781894,
#          0.4117562 , -0.95329201],
#        [-0.35204544, -0.29551048, -0.15691394, ...,  0.39952464,
#         -1.46578168, -0.95329201],
#        [ 1.23049789,  0.82260896,  0.92326138, ...,  0.09675987,
#         -1.46578168,  1.04899652],
#        ...,
#        [-1.30157144,  0.82260896,  2.00343669, ...,  0.09675987,
#          0.4117562 , -0.95329201],
#        [-1.17496798,  0.82260896,  0.92326138, ...,  0.09675987,
#          0.4117562 , -0.95329201],
#        [-1.42817491, -1.41362991, -1.23708926, ..., -0.50876966,
#          1.35052513,  1.04899652]])

# %%
x_test
# Out:
# array([[-0.35204544, -2.53174935, -2.31726458, ...,  0.39952464,
#          1.35052513, -0.95329201],
#        [-1.30157144, -0.29551048, -0.15691394, ...,  0.70228941,
#          0.4117562 ,  1.04899652],
#        [-0.22544197, -1.41362991, -1.23708926, ..., -0.81153443,
#          0.4117562 ,  1.04899652],
#        ...,
#        [-0.03553677, -0.29551048, -1.23708926, ...,  0.70228941,
#          1.35052513,  1.04899652],
#        [-0.47864891,  0.82260896,  0.92326138, ..., -0.81153443,
#          1.35052513,  1.04899652],
#        [-1.74468358, -0.29551048,  0.92326138, ...,  0.70228941,
#          0.4117562 , -0.95329201]])

# %% [markdown]
# # Logistic Regression

# %%
# LR with all default parameters
from sklearn.linear_model import LogisticRegression

# %%
classifier_lr = LogisticRegression(random_state=0)

# %%
classifier_lr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Pred test
y_pred = classifier_lr.predict(x_test)

# %%
# Analyse the performance of LR model: there are several ways
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
accuracy= accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

# %%
results = pd.DataFrame([['Logistic Regression', accuracy, f1, precision, rec]],
                      columns = ['Model', 'Accuracy', 'F1 score', 'Precision', 'Recall'])

# %%
results
# Out:
#                  Model  Accuracy  F1 score  Precision    Recall
# 0  Logistic Regression  0.823144  0.878195   0.866469  0.890244

# %%
# Pred train
y_pred2 = classifier_lr.predict(x_train)

# %%
accuracy1= accuracy_score(y_train, y_pred2)
f11 = f1_score(y_train, y_pred2)
precision1 = precision_score(y_train, y_pred2)
rec1 = recall_score(y_train, y_pred2)

# %%
results2 = pd.DataFrame([['Logistic Regression1', accuracy1, f11, precision1, rec1]],
                      columns = ['Model', 'Accuracy', 'F1 score', 'Precision', 'Recall'])

# %%
results2
# Out:
#                   Model  Accuracy  F1 score  Precision    Recall
# 0  Logistic Regression1  0.839738  0.886379   0.866234  0.907483

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 85  45]
#  [ 36 292]]

# %%
Logistic_model = LogisticRegression(solver='newton-cg',max_iter=10000,penalty='none',verbose=True,n_jobs=2)
Logistic_model.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 out of   1 | elapsed:    0.8s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=2, penalty='none',
#                    random_state=None, solver='newton-cg', tol=0.0001,
#                    verbose=True, warm_start=False)

# %% [markdown]
# # AUC ROC curve for Logistic Regression

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
probs_train=Logistic_model.predict_proba(x_train)
probs_train=probs_train[:, 1]
auc=roc_auc_score(y_train,probs_train)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train,probs_train)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.889

# %%
probs_test_lr=Logistic_model.predict_proba(x_test)
probs_test_lr=probs_test_lr[:, 1]
auc=roc_auc_score(y_test,probs_test_lr)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_lr)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.882

# %% [markdown]
# # Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,roc_curve
from sklearn.preprocessing import scale

# %%
clf = LinearDiscriminantAnalysis()

# %%
model1=clf.fit(x_train,y_train)
model1
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
# Predict test
pred_class = model1.predict(x_test)

# %%
print(classification_report(y_test, pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.66      0.67       130
#            1       0.87      0.88      0.87       328
#
#     accuracy                           0.82       458
#    macro avg       0.78      0.77      0.77       458
# weighted avg       0.82      0.82      0.82       458

# %%
# Predict train
pred_class1 = model1.predict(x_train)

# %%
print(classification_report(y_train, pred_class1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73       332
#            1       0.87      0.90      0.88       735
#
#     accuracy                           0.84      1067
#    macro avg       0.81      0.80      0.81      1067
# weighted avg       0.83      0.84      0.84      1067

# %%
from sklearn import metrics

# %%
print(metrics.confusion_matrix(y_test,pred_class))
# Out:
# [[ 86  44]
#  [ 39 289]]

# %%
probs_test_ldr=Logistic_model.predict_proba(x_test)
probs_test_ldr=probs_test_ldr[:, 1]
auc=roc_auc_score(y_test,probs_test_ldr)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_ldr)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.882

# %% [markdown]
# # Building KNN Model

# %%
#from sklearn.neighbors import KNeighborsClassifier

from sklearn.neighbors import KNeighborsClassifier

KNN_Model = KNeighborsClassifier()
KNN_Model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# # Evaluating performance of KNN Model

# %%
Y_train_predict=KNN_Model.predict(x_train)
KNN_Model_score=KNN_Model.score(x_train,y_train)

# %%
print(KNN_Model_score)
# Out:
# 0.8631677600749765

# %%
# calculate accuracy measures and confusion matrix

from sklearn import metrics
print('confusion matrix')
print(metrics.confusion_matrix(y_train,Y_train_predict))
print(metrics.classification_report(y_train,Y_train_predict))
# Out:
# confusion matrix
# [[248  84]
#  [ 62 673]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77       332
#            1       0.89      0.92      0.90       735
#
#     accuracy                           0.86      1067
#    macro avg       0.84      0.83      0.84      1067
# weighted avg       0.86      0.86      0.86      1067

# %% [markdown]
# # AUC ROC for KNN Train

# %%
probs_train=KNN_Model.predict_proba(x_train)
probs_train=probs_train[:, 1]
auc=roc_auc_score(y_train,probs_train)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train,probs_train)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.932

# %%
y_test_predict=KNN_Model.predict(x_test)

KNN_Model_score=KNN_Model.score(x_test, y_test)

print(KNN_Model_score)
# Out:
# 0.8253275109170306

# %%
print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# [[ 92  38]
#  [ 42 286]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70       130
#            1       0.88      0.87      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.78      0.79      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %% [markdown]
# # AUC ROC for KNN Test

# %%
probs_test=KNN_Model.predict_proba(x_test)
probs_test=probs_test[:,1]
auc=roc_auc_score(y_test,probs_test)
print("the auc curve %.3f " % auc)

test_fpr,test_tpr,test_threshold=roc_curve(y_test,probs_test)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr, test_tpr)
# Out:
# the auc curve 0.871

# %%
KNN_model=KNeighborsClassifier(n_neighbors=7)
KNN_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
KNN_model=KNeighborsClassifier(n_neighbors=7)
KNN_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
y_train_predict=KNN_model.predict(x_train)
KNN_model_score=KNN_model.score(x_train,y_train)
print(KNN_model_score)
print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8500468603561387
# [[240  92]
#  [ 68 667]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75       332
#            1       0.88      0.91      0.89       735
#
#     accuracy                           0.85      1067
#    macro avg       0.83      0.82      0.82      1067
# weighted avg       0.85      0.85      0.85      1067

# %%
y_test_predict=KNN_model.predict(x_test)
KNN_model_score=KNN_model.score(x_test,y_test)
print(KNN_model_score)
print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8318777292576419
# [[ 93  37]
#  [ 40 288]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71       130
#            1       0.89      0.88      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.79      0.80      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
KNN_model=KNeighborsClassifier(n_neighbors=5)
KNN_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_train_predict=KNN_model.predict(x_train)
KNN_model_score=KNN_model.score(x_train,y_train)
print(KNN_model_score)
print(metrics.confusion_matrix(y_train,y_train_predict))
print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8631677600749765
# [[248  84]
#  [ 62 673]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77       332
#            1       0.89      0.92      0.90       735
#
#     accuracy                           0.86      1067
#    macro avg       0.84      0.83      0.84      1067
# weighted avg       0.86      0.86      0.86      1067

# %%
y_test_predict=KNN_model.predict(x_test)
KNN_model_score=KNN_model.score(x_test,y_test)
print(KNN_model_score)
print(metrics.confusion_matrix(y_test,y_test_predict))
print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8253275109170306
# [[ 92  38]
#  [ 42 286]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70       130
#            1       0.88      0.87      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.78      0.79      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
ac_score=[]

for k in range(1,20,2):
    knn= KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    scores=knn.score(x_test,y_test)
    ac_score.append(scores)
    
MCE=[1-x for x in ac_score]
MCE
# Out:
# [0.22925764192139741,
#  0.19213973799126638,
#  0.1746724890829694,
#  0.16812227074235808,
#  0.17685589519650657,
#  0.18122270742358082,
#  0.17685589519650657,
#  0.17903930131004364,
#  0.16375545851528384,
#  0.17030567685589515]

# %% [markdown]
# # AUC ROC curve & classifier for train dataset

# %%
probs_train=knn.predict_proba(x_train)
probs_train=probs_train[:,1]
auc=roc_auc_score(y_train,probs_train)
print("the auc curve %.3f " % auc)

train_fpr,train_tpr,train_threshold=roc_curve(y_train,probs_train)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr, test_tpr)
# Out:
# the auc curve 0.902

# %% [markdown]
# # AUC ROC curve & classifier for test dataset

# %%
probs_test=knn.predict_proba(x_test)
probs_test=probs_test[:,1]
auc=roc_auc_score(y_test,probs_test)
print("the auc curve %.3f " % auc)

test_fpr,test_tpr,test_threshold=roc_curve(y_test,probs_test)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr, test_tpr)
# Out:
# the auc curve 0.896

# %%
import matplotlib.pyplot as plt

# plot misclassification error vs k
plt.plot(range(1,20,2), MCE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
NB_model=GaussianNB()
NB_model.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#Performance of model with Train data

# %%
y_train_predict=NB_model.predict(x_train)
model_score=NB_model.score(x_train, y_train)
print(model_score)
print(metrics.confusion_matrix(y_train,y_train_predict))

print(metrics.classification_report(y_train,y_train_predict))
# Out:
# 0.8331771321462043
# [[240  92]
#  [ 86 649]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       332
#            1       0.88      0.88      0.88       735
#
#     accuracy                           0.83      1067
#    macro avg       0.81      0.80      0.80      1067
# weighted avg       0.83      0.83      0.83      1067

# %%
#AUC ROC curve for Train data

# %%
probs_train=NB_model.predict_proba(x_train)
probs_train=probs_train[:, 1]
auc=roc_auc_score(y_train,probs_train)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train,probs_train)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.886

# %%
#Performace of data with Test data

# %%
y_test_predict=NB_model.predict(x_test)
model_score=NB_model.score(x_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test,y_test_predict))

print(metrics.classification_report(y_test,y_test_predict))
# Out:
# 0.8253275109170306
# [[ 94  36]
#  [ 44 284]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       130
#            1       0.89      0.87      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.78      0.79      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
#AUC ROC Curve for test data

# %%
probs_test=NB_model.predict_proba(x_test)
probs_test=probs_test[:,1]
auc=roc_auc_score(y_test,probs_test)
print("the auc curve %.3f " % auc)

test_fpr,test_tpr,test_threshold=roc_curve(y_test,probs_test)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr, test_tpr)
# Out:
# the auc curve 0.885

# %%
plt.rcParams['figure.figsize'] = (7,5)
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Lets build models

# %% [markdown]
# # Model tuning - Bagging,(Random Forest) and Boosting

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import classification_report, f1_score

# %%
#lets balance the dataset

# %%
# !pip3 install imblearn
# Out:
# 'pip3' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from imblearn.over_sampling import SMOTE
# Out:
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ...

# %%
sm = SMOTE( random_state = 1)
x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)
# Out:
# C:\Users\nray\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=1)
dt.fit(x_train_sm, y_train_sm)

train_pred_dt = dt.predict(x_train_sm)
test_pred_dt = dt.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_dt))
print('Test F1: ', f1_score(y_test, test_pred_dt))
print('\n')
print(classification_report(y_test, test_pred_dt))
# Out:
# Train F1:  0.9993192648059904
# Test F1:  0.8169014084507042
#
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.62      0.58       130
#            1       0.84      0.80      0.82       328
#
#     accuracy                           0.74       458
#    macro avg       0.69      0.71      0.70       458
# weighted avg       0.76      0.74      0.75       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_dt))
# Out:
# [[ 80  50]
#  [ 67 261]]

# %%
probs_train_dt=dt.predict_proba(x_train_sm)
probs_train_dt=probs_train_dt[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_dt)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_dt)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 1.000

# %%
probs_test_dt=dt.predict_proba(x_test)
probs_test_dt=probs_test_dt[:, 1]
auc=roc_auc_score(y_test,probs_test_dt)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_dt)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.706

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=1)
rf.fit(x_train_sm, y_train_sm)

train_pred_rf = rf.predict(x_train_sm)
test_pred_rf = rf.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_rf))
print('Test F1: ', f1_score(y_test, test_pred_rf))
print('\n')
print(classification_report(y_test, test_pred_rf))
# Out:
# Train F1:  0.9993201903467028
# Test F1:  0.8637770897832818
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       130
#            1       0.88      0.85      0.86       328
#
#     accuracy                           0.81       458
#    macro avg       0.76      0.78      0.77       458
# weighted avg       0.81      0.81      0.81       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_rf))
# Out:
# [[ 91  39]
#  [ 49 279]]

# %%
probs_train_rf=rf.predict_proba(x_train_sm)
probs_train_rf=probs_train_rf[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_rf)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_rf)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 1.000

# %%
probs_test_rf=rf.predict_proba(x_test)
probs_test_rf=probs_test_rf[:, 1]
auc=roc_auc_score(y_test,probs_test_rf)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_rf)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.880

# %% [markdown]
# ## Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

# %%
be = RandomForestClassifier()

# %%
bag = BaggingClassifier(base_estimator= be, n_estimators= 10, random_state=1 )
bag.fit(x_train_sm, y_train_sm)

train_pred_bag = bag.predict(x_train_sm)
test_pred_bag = bag.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_bag))
print('Test F1: ', f1_score(y_test, test_pred_bag))
print('\n')
print(classification_report(y_test, test_pred_bag))
# Out:
# Train F1:  0.9755434782608695
# Test F1:  0.8771384136858477
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71       130
#            1       0.90      0.86      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.79      0.80      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_bag))
# Out:
# [[ 97  33]
#  [ 46 282]]

# %%
probs_train_ba=bag.predict_proba(x_train_sm)
probs_train_ba=probs_train_ba[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_ba)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_ba)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.998

# %%
probs_test_ba=bag.predict_proba(x_test)
probs_test_ba=probs_test_ba[:, 1]
auc=roc_auc_score(y_test,probs_test_ba)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_ba)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.895

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adb = DecisionTreeClassifier(max_depth=1)

# %%
ada = AdaBoostClassifier(base_estimator=adb, n_estimators= 100, random_state=1, learning_rate=0.1)
ada=ada.fit(x_train_sm, y_train_sm)

train_pred_ada = ada.predict(x_train_sm)
test_pred_ada = ada.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_ada))
print('Test F1: ', f1_score(y_test, test_pred_ada))
print('\n')
print(classification_report(y_test, test_pred_ada))
# Out:
# Train F1:  0.8459958932238193
# Test F1:  0.8421052631578947
#
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.82      0.69       130
#            1       0.91      0.78      0.84       328
#
#     accuracy                           0.79       458
#    macro avg       0.75      0.80      0.77       458
# weighted avg       0.82      0.79      0.80       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_ada))
# Out:
# [[106  24]
#  [ 72 256]]

# %%
probs_train_ada=ada.predict_proba(x_train_sm)
probs_train_ada=probs_train_ada[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_ada)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_ada)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.918

# %%
probs_test_ada=ada.predict_proba(x_test)
probs_test_ada=probs_test_ada[:, 1]
auc=roc_auc_score(y_test,probs_test_ada)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_ada)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.890

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators= 100, random_state=1)
gbc.fit(x_train_sm, y_train_sm)

train_pred_gb = gbc.predict(x_train_sm)
test_pred_gb = gbc.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_gb))
print('Test F1: ', f1_score(y_test, test_pred_gb))
print('\n')
print(classification_report(y_test, test_pred_gb))
# Out:
# Train F1:  0.908716540837337
# Test F1:  0.8688783570300158
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.71       130
#            1       0.90      0.84      0.87       328
#
#     accuracy                           0.82       458
#    macro avg       0.78      0.80      0.79       458
# weighted avg       0.83      0.82      0.82       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_gb))
# Out:
# [[100  30]
#  [ 53 275]]

# %%
probs_train_gbc=gbc.predict_proba(x_train_sm)
probs_train_gbc=probs_train_gbc[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_gbc)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_gbc)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.970

# %%
probs_test_gbc=gbc.predict_proba(x_test)
probs_test_gbc=probs_test_gbc[:, 1]
auc=roc_auc_score(y_test,probs_test_gbc)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_gbc)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.892

# %% [markdown]
# ## Lets tune GBC further since this the best performing one

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'n_estimators': [50, 100, 150],
          'min_samples_split':[2, 5, 7],
          'max_depth': [1, 3, 5]}

# %%
# %%time
gbc = GradientBoostingClassifier(random_state=1 )
grid_gbc = GridSearchCV(gbc, param_grid = params, verbose=1, cv = 3, scoring='f1')
grid_gbc.fit(x_train_sm, y_train_sm)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:   14.5s finished
# Wall time: 15.1 s
# GridSearchCV(cv=3, error_score=nan,
#              estimator=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                   criterion='friedman_mse',
#                                                   init=None, learning_rate=0.1,
#                                                   loss='deviance', max_depth=3,
#                                                   max_features=None,
#                                                   max_leaf_nodes=None,
#                                                   min_impurity_decrease=0.0,
#                                                   min_impurity_split=None,
#                                                   min_samples_leaf=1,
# ...

# %%
grid_gbc.best_params_
# Out:
# {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 150}

# %%
grid_gbc.best_score_
# Out:
# 0.85340923153089

# %%
train_pred_gbc = grid_gbc.predict(x_train_sm)
test_pred_gbc = grid_gbc.predict(x_test)

print('Train F1: ', f1_score(y_train_sm, train_pred_gbc))
print('Test F1: ', f1_score(y_test, test_pred_gbc))
print('\n')
print(classification_report(y_test, test_pred_gbc))
# Out:
# Train F1:  0.9850948509485095
# Test F1:  0.8566978193146417
#
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.70      0.66       130
#            1       0.88      0.84      0.86       328
#
#     accuracy                           0.80       458
#    macro avg       0.75      0.77      0.76       458
# weighted avg       0.81      0.80      0.80       458

# %%
print(metrics.confusion_matrix(y_test,test_pred_gbc))
# Out:
# [[ 91  39]
#  [ 53 275]]

# %%
probs_train_grid_gbc=grid_gbc.predict_proba(x_train_sm)
probs_train_grid_gbc=probs_train_grid_gbc[:, 1]
auc=roc_auc_score(y_train_sm,probs_train_grid_gbc)
print("the auc %.3f " % auc)
train_fpr ,train_tpr, train_thresholds= roc_curve(y_train_sm,probs_train_grid_gbc)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(train_fpr,train_tpr);
# Out:
# the auc 0.999

# %%
probs_test_grid_gbc=grid_gbc.predict_proba(x_test)
probs_test_grid_gbc=probs_test_grid_gbc[:, 1]
auc=roc_auc_score(y_test,probs_test_grid_gbc)
print("the auc %.3f " % auc)
test_fpr ,test_tpr, test_thresholds= roc_curve(y_test,probs_test_grid_gbc)
plt.plot([0,1],[0,1],linestyle='--')
plt.plot(test_fpr,test_tpr);
# Out:
# the auc 0.866
